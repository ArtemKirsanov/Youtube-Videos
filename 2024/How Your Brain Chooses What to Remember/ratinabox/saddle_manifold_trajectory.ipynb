# %%
import ratinabox
from ratinabox import Environment, Agent
from ratinabox.Neurons import PlaceCells
import numpy as np
import shapely
import matplotlib.pyplot as plt
import pickle

# %%
Env = Environment()
Ag = Agent(Env)

for i in range(3000):
    Ag.update()

# %%
Ag.plot_trajectory()
# Out:
# (<Figure size 250x250 with 1 Axes>, <Axes: >)

# %%
with open("ratinabox_output_saddle_manifold.pickle", "wb") as f:
    pickle.dump({"Environment":Env, "Agent":Ag}, f)
